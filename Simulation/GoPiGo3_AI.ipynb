# %%
# Importing libraries...
import time
import numpy as np
from coppeliasim_zmqremoteapi_client import RemoteAPIClient

from pid import PID

# Init client
client = RemoteAPIClient()  # Client object
sim = client.getObject("sim")  # Simulation object

# %%
class Individual:
    def __init__(
        self,
        genome = np.array([])
    ):
        self.genome = genome
        self.metrics = np.array([])
        self.fitness = -np.inf

# %%
def init_population(population_size, genome_lenght):
    return np.random.uniform(0.0, 10.0, (population_size, genome_lenght))


def crossover(genome_x, genome_y, crossover_rate):
    if np.random.rand() < crossover_rate:
        c = np.random.randint(0, len(genome_x) - 1)

        return np.concatenate((genome_x[:c], genome_y[c:])), np.concatenate((genome_y[:c], genome_x[c:]))
    else:
        return genome_x, genome_y


def mutate(genome, mutation_rate):
    new_genome = genome * np.random.uniform(1.0 - mutation_rate, 1.0 + mutation_rate, len(genome)) # It can drop or rise by 25%
    return new_genome


def get_fitness(metrics, weights):
    return np.dot(metrics, weights)


def pick_fittest(population, fitness_values):
    return population[np.argsort(fitness_values)][-2:] # Pick fittest parents

# %%
'''class Population:
    def __init__(
        self,
        individual_type = Individual,
        size=2,
        crossover_rate=0.0,
        mutation_rate=0.0,
        weights=np.array([])
    ):
        self.individual_type = individual_type
        self.size = size
        self.crossover_rate= crossover_rate,
        self.mutation_rate= mutation_rate,
        self.weights= weights

        self.individuals = []

    def init_population(self, lower_guess, higher_guess):
        # Create a list of random genome individuals with the size of the population
        self.individuals = [self.individual_type(
            genome=np.random.uniform(lower_guess, higher_guess, len(self.individual_type.genome))
        )

        for _ in range(self.size)]

    def crossover(self, genome_x, genome_y):
        # Crossover
        if np.random.rand() < self.crossover_rate: 
            c = np.random.randint(0, len(self.individual_type.genome) - 1)

            return np.concatenate((genome_x[:c], genome_y[c:])), np.concatenate((genome_y[:c], genome_x[c:]))

        # Don't crossover
        else:
            return genome_x, genome_y
        
    
    def mutate(self):
        for individual in self.individuals:
            # Drop or rise parameters by mutation_rate%
            individual.genome *= np.random.uniform(1.0 - self.mutation_rate, 1.0 + self.mutation_rate, len(self.individual_type.genome))


    def update_fitness(self):
        for individual in self.individuals:
            individual.fitness = np.dot(individual.metrics, self.weights)


    def order_by_fittest(self):
        fitness_values = [individual.fitness for individual in self.individuals]
        sorted_indexes = np.argsort(fitness_values)
        self.individuals = [self.individuals[index] for index in sorted_indexes]
        '''
# Out:
# "class Population:\n    def __init__(\n        self,\n        individual_type = Individual,\n        size=2,\n        crossover_rate=0.0,\n        mutation_rate=0.0,\n        weights=np.array([])\n    ):\n        self.individual_type = individual_type\n        self.size = size\n        self.crossover_rate= crossover_rate,\n        self.mutation_rate= mutation_rate,\n        self.weights= weights\n\n        self.individuals = []\n\n    def init_population(self, lower_guess, higher_guess):\n        # Create a list of random genome individuals with the size of the population\n        self.individuals = [self.individual_type(\n            genome=np.random.uniform(lower_guess, higher_guess, len(self.individual_type.genome))\n        )\n\n        for _ in range(self.size)]\n\n    def crossover(self, genome_x, genome_y):\n        # Crossover\n        if np.random.rand() < self.crossover_rate: \n            c = np.random.randint(0, len(self.individual_type.genome) - 1)\n\n            return np.concatenate((genome_x[:c], genome_y[c:])), np.concatenate((genome_y[:c], genome_x[c:]))\n\n        # Don't crossover\n        else:\n            return genome_x, genome_y\n        \n    \n    def mutate(self):\n        for individual in self.individuals:\n            # Drop or rise parameters by mutation_rate%\n            individual.genome *= np.random.uniform(1.0 - self.mutation_rate, 1.0 + self.mutation_rate, len(self.individual_type.genome))\n\n\n    def update_fitness(self):\n        for individual in self.individuals:\n            individual.fitness = np.dot(individual.metrics, self.weights)\n\n\n    def order_by_fittest(self):\n        fitness_values = [individual.fitness for individual in self.individuals]\n        sorted_indexes = np.argsort(fitness_values)\n        self.individuals = [self.individuals[index] for index in sorted_indexes]\n        "

# %%
class GoPiGo3(Individual):
    def __init__(
        self,
        # CoppeliaSim Handle
        handle_name = "/GoPiGo3",
        target_handle_name = "/Target",
        # Controllers
        genome = np.zeros(6)
    ):
        # Individual's inherited properties
        Individual.__init__(
            self, 
            genome=genome
        )

        # Handles
        self.handle = sim.getObject(handle_name)
        self.target_handle = sim.getObject(target_handle_name)
        self.motor_L_handle = sim.getObject(handle_name + "/LeftJoint")
        self.motor_R_handle = sim.getObject(handle_name + "/RightJoint")

        # Controllers
        self.OrientationController = PID(
            K_p=genome[0], 
            K_i=genome[1], 
            K_d=genome[2], 
            dt=sim.getSimulationTimeStep()
        )
        self.VelocityController = PID(
            K_p=genome[3], 
            K_i=genome[4], 
            K_d=genome[5], 
            dt=sim.getSimulationTimeStep()
        )

        # Differential Drive Model Parameters
        self.r = 0.2823
        self.s = 0.120

        # Metrics
        self.not_converged = True
        self.convergence_time = np.inf
        self.convergence_distance = np.inf
        self.target_distance = np.inf
        self.max_roll = 0.0
        self.max_pitch = 0.0

    def sense_and_actuate(self):
        timestamp = sim.getSimulationTime()

        # Getting GoPiGo3 Differential Drive Model Position
        position = np.mean(
            [
                sim.getObjectPosition(self.motor_L_handle), 
                sim.getObjectPosition(self.motor_R_handle)
            ],
            axis=0,
        )[:2]

        # Vectors and distances
        front_vector = np.array(sim.getObjectMatrix(self.handle)).reshape(3, 4)[:2, 0]
        roll, pitch, _ = np.abs(sim.getObjectOrientation(self.handle))
        path_vector = np.array(sim.getObjectPosition(self.target_handle))[:2] - position
        target_distance = np.linalg.norm(path_vector)
        target_vector = path_vector / target_distance

        # Error signals
        orientation_error = np.cross(front_vector, target_vector)
        position_error = np.dot(front_vector, target_vector) * target_distance

        # Controllers
        theta_dot = self.OrientationController.get_output(orientation_error)
        v_B = self.VelocityController.get_output(position_error)

        # Differential Drive Model
        theta_dot_L, theta_dot_R = np.linalg.inv(
            [
                [self.r / 2.0, self.r / 2.0], 
                [-self.r / self.s, self.r / self.s]
            ]
        ) @ np.array([v_B, theta_dot])

        # Update target distance
        self.target_distance = target_distance
        
        # Update max roll and max pitch
        if self.max_roll < roll: 
            self.max_roll = roll
        if self.max_pitch < pitch: 
            self.max_pitch = pitch

        # Convergence criteria
        self.not_converged = self.target_distance > 0.05

        # Stop condition
        if self.not_converged:
            # Move joints
            sim.setJointTargetVelocity(self.motor_L_handle, theta_dot_L)
            sim.setJointTargetVelocity(self.motor_R_handle, theta_dot_R)

            # Update convergence time
            self.convergence_time = timestamp

        else:
            # Move joints
            sim.setJointTargetVelocity(self.motor_L_handle, 0.0)
            sim.setJointTargetVelocity(self.motor_R_handle, 0.0)


    def get_metrics(self):
        # Returning vectorized performance parameters
        return np.array(
            [
                self.not_converged, 
                self.convergence_time, 
                self.target_distance,
                self.max_roll,
                self.max_pitch
            ]
        )

# %%
# Resetting Individuals
def reset_individuals(population_size):
    while True:
        try:
            sim.removeModel(sim.getObject(f"/Individual[1]"))
        except:
            break

    base_handle = sim.getObject("/Individual")
    for _ in range(population_size - 1):
        sim.copyPasteObjects([base_handle], 1)

# %%
# Simulation batch
simulation_time = 5.0
target_lower_bound = 0.1
target_higher_bound = 1.0

generations = 50
population_size = 10
crossover_rate = 0.10
mutation_rate = 0.25
weights = np.array([-40.0, -1.0, -20.0, -50.0, -50.0])

population = init_population(population_size, 6)
fitness_values = None

reset_individuals(population_size)

for generation, r in enumerate(np.linspace(target_lower_bound, target_higher_bound, generations)):
    print(f"Generation {generation}: Target at {r} m")

    # Set target to random position for this generation to pursue     
    theta = np.random.uniform(0.0, 2 * np.pi)
    x = r * np.cos(theta)
    y = r * np.sin(theta)
        
    sim.setObjectPosition(
        sim.getObject('/Target'),
        [x, y, 0.05]
    )

    robot_population = [
        GoPiGo3(
            handle_name=f"/Individual[{i}]/GoPiGo3",
            target_handle_name="/Target",
            genome=genome
        )
        
        for i, genome in enumerate(population)
    ]

    try:
        sim.setStepping(True)  # Trigger simulation step manually

        # Start simulation
        sim.startSimulation()

        while sim.getSimulationTime() < simulation_time:
            for robot in robot_population:
                
                robot.sense_and_actuate()

            sim.step() # Call for next step

        # Stop simulation
        sim.stopSimulation()
        time.sleep(1.0) # Wait for simulation to stop

    except:
        pass
    
    # Get fitnes of every individual of the population
    fitness_values = [get_fitness(robot.get_metrics(), weights) for robot in robot_population]

    for robot, fitness_value in zip(robot_population, fitness_values):
        metrics = robot.get_metrics()
        
        print(f"Not converged: {robot.not_converged}") 
        print(f"Convergence time: {robot.convergence_time:.2f}") 
        print(f"Target distance: {robot.target_distance:.2f}") 
        print(f"Max roll: {robot.max_roll:.3f}") 
        print(f"Max pitch: {robot.max_pitch:.3f}") 
        print()
        print(robot.genome)
        print()
        print(f"Fitness: {fitness_value:.2f}", '\n\n')

    # Pick fittest and have them make them have offspring
    parent_x, parent_y = pick_fittest(population, fitness_values)

    # If it is on last generation, do not crossover and mutate
    if generation >= generations - 1:
        break

    # Make a new population based on variants of the most adapted individuals 
    new_population = []
    offspring_x, offspring_y = crossover(parent_x, parent_y, crossover_rate)

    for _ in range(population_size // 2):
        new_population.append(mutate(offspring_x, mutation_rate))
        new_population.append(mutate(offspring_y, mutation_rate))

    # Update population
    population = np.array(new_population)
# Out:
# Generation 0: Target at 0.1 m
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.049605522527326966
# Max roll:  0.00024280780897672173
# Max pitch:  0.0005752803649910943
#
# [0.20373496 3.83485157 8.98391597 8.1051372  1.34480656 3.04559154]
#
# Fitness:  -2.6330148592449305
#
#
# Not converged:  False
# Convergence time:  1.1000000000000003
# Target distance:  0.04880109614850903
# Max roll:  0.00013465438639084255
# Max pitch:  0.00019127600176248262
#
# [5.29817461 8.22835153 1.08327509 5.96216807 2.90710055 5.43013593]
#
# Fitness:  -2.0923184423778474
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.0486972692906385
# Max roll:  0.00013981705415301872
# Max pitch:  0.0007842952826232058
#
# [0.3253004  5.84660145 2.21443053 6.50404616 6.32511172 5.23835712]
#
# Fitness:  -2.3701510026515815
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.049631834639708425
# Max roll:  0.00021221275458384745
# Max pitch:  0.0005909516041290009
#
# [1.27015492 0.56439992 7.80360621 7.9911407  6.68977561 4.46993437]
#
# Fitness:  -2.582794910729812
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.04846032816868654
# Max roll:  0.0002860320072380906
# Max pitch:  0.0009259488295639276
#
# [4.74371959 1.62036486 9.90845409 6.6161312  7.41677444 1.92279091]
#
# Fitness:  -2.079805605213832
#
#
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.04916081176009348
# Max roll:  0.00031558398861411747
# Max pitch:  0.0004890870567788159
#
# [4.15797413 1.30059482 2.55996852 4.7515102  2.45239332 6.23916774]
#
# Fitness:  -2.6234497874715172
#
#
# Not converged:  False
# Convergence time:  1.1500000000000004
# Target distance:  0.049645561183763696
# Max roll:  0.00022052639333501096
# Max pitch:  0.00030791562621458216
#
# [6.78643551 1.73443065 4.54789934 7.46149244 0.68439081 1.17530653]
#
# Fitness:  -2.1693333246527544
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.04886724984862826
# Max roll:  0.00038152415004724676
# Max pitch:  0.0004429990371969291
#
# [6.19280631 6.07600645 7.88699736 6.94241981 0.27945641 0.1411481 ]
#
# Fitness:  -2.2185711563347743
#
#
# Not converged:  False
# Convergence time:  0.8000000000000002
# Target distance:  0.04832917461377323
# Max roll:  0.0005438582498150939
# Max pitch:  0.0007194315291414373
#
# [9.89318029 5.56882544 2.7120075  6.1556778  8.15897025 1.66977062]
#
# Fitness:  -1.829747981223291
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.04870803288433517
# Max roll:  0.0005896306848326904
# Max pitch:  0.0007781908134204217
#
# [2.48580559 6.49971962 8.97333767 6.44343204 1.66823595 0.50519762]
#
# Fitness:  -2.3425517325993597
#
#
# Generation 1: Target at 0.11836734693877551 m
# Not converged:  False
# Convergence time:  3.8499999999999943
# Target distance:  0.049599064151601945
# Max roll:  0.00038239293813532106
# Max pitch:  0.0005023428023910593
#
# [4.37536748 1.25153614 7.86362224 5.54963372 7.02340601 1.92151894]
#
# Fitness:  -4.886218070058352
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.0431251683133363
# Max roll:  0.0006227249947192924
# Max pitch:  0.0005520640126350766
#
# [8.07259422 6.94677407 3.16568677 5.78854775 8.63937572 2.0281991 ]
#
# Fitness:  -2.721242816634445
#
#
# Not converged:  False
# Convergence time:  2.799999999999998
# Target distance:  0.04814497702222708
# Max roll:  0.0009362024183367319
# Max pitch:  0.00028828522908674225
#
# [5.56344918 1.92833943 8.85825528 5.17207432 7.91669344 2.00039434]
#
# Fitness:  -3.824123922815714
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.04596920192479075
# Max roll:  0.000667495721255105
# Max pitch:  0.0008250075302920631
#
# [9.93575718 6.57922065 2.70099792 5.78411764 6.64902945 1.79212917]
#
# Fitness:  -2.7440092010731743
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.05983710471201024
# Max roll:  0.0009691562781832323
# Max pitch:  0.0004713175699035292
#
# [ 4.33650303  1.55040723 11.84798102  8.08883715  9.23480172  2.10332039]
#
# Fitness:  -46.268765786644536
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.043938425477341725
# Max roll:  0.00021046171312308522
# Max pitch:  0.00022850486026128398
#
# [9.24666786 5.17991636 2.47755546 5.94663296 8.26363512 1.43580351]
#
# Fitness:  -2.7007168382160542
#
#
# Not converged:  False
# Convergence time:  3.099999999999997
# Target distance:  0.04820525856251932
# Max roll:  0.00028805145830760416
# Max pitch:  0.00034075499840227364
#
# [ 4.94449417  1.94565992 12.10321056  6.77706999  8.48278802  1.70507228]
#
# Fitness:  -4.0955454940858775
#
#
# Not converged:  False
# Convergence time:  1.900000000000001
# Target distance:  0.04119925985436015
# Max roll:  0.0008079824583522166
# Max pitch:  0.0005422316787445689
#
# [8.40823272 4.74934332 3.24784766 6.36415799 9.85810578 1.93146323]
#
# Fitness:  -2.7914959039420437
#
#
# Not converged:  False
# Convergence time:  3.2999999999999963
# Target distance:  0.04717303485477549
# Max roll:  0.0006381859787898647
# Max pitch:  0.0005346011003284337
#
# [4.9995918  1.50714102 9.39856258 7.01073084 5.83646201 2.13719477]
#
# Fitness:  -4.30210005105142
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.04626372310420931
# Max roll:  0.0008282859916235391
# Max pitch:  0.00041668765818241596
#
# [9.70326946 5.04249639 3.08921174 4.96281983 6.89344808 1.48263781]
#
# Fitness:  -2.837523144574485
#
#
# Generation 2: Target at 0.13673469387755102 m
# Not converged:  False
# Convergence time:  3.899999999999994
# Target distance:  0.04837399897817849
# Max roll:  0.0009599955752307862
# Max pitch:  0.000943063971912018
#
# [7.47178407 5.44699049 3.68716689 6.06799897 8.56004967 2.34880248]
#
# Fitness:  -4.962632956920705
#
#
# Not converged:  False
# Convergence time:  3.699999999999995
# Target distance:  0.04999611500218831
# Max roll:  0.0008041987936348878
# Max pitch:  0.00047227644301099577
#
# [8.97297834 4.57380819 2.31084858 6.85910481 6.52314568 1.69791572]
#
# Fitness:  -4.763746061876056
#
#
# Not converged:  False
# Convergence time:  4.099999999999993
# Target distance:  0.049422057374397074
# Max roll:  0.0007067916765815122
# Max pitch:  0.0006268319769008561
#
# [8.26159264 5.80382616 2.45580197 5.65859606 8.03790602 2.04752171]
#
# Fitness:  -5.155122330162054
#
#
# Not converged:  False
# Convergence time:  1.1000000000000003
# Target distance:  0.04446885921803075
# Max roll:  0.00015151453592479198
# Max pitch:  0.0007672554951401008
#
# [7.72508839 4.37598858 2.94195245 6.0937648  9.64807077 1.6421791 ]
#
# Fitness:  -2.03531568591386
#
#
# Not converged:  False
# Convergence time:  1.1000000000000003
# Target distance:  0.04619898235664065
# Max roll:  0.0003527665620517861
# Max pitch:  0.00048406687608798353
#
# [7.24934553 7.96290876 2.72524221 6.07569482 9.65900209 1.85207937]
#
# Fitness:  -2.065821319039802
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.04722946752100645
# Max roll:  0.0006123734151846014
# Max pitch:  0.0009662579283912482
#
# [8.67091145 4.05075828 2.65072774 6.35747949 7.26608255 1.12922454]
#
# Fitness:  -2.2235209175989215
#
#
# Not converged:  False
# Convergence time:  3.899999999999994
# Target distance:  0.048751729434008864
# Max roll:  0.0006009119599534131
# Max pitch:  0.00036545340996526124
#
# [9.67080282 7.58263073 2.56729846 4.73171726 9.15038405 1.62349597]
#
# Fitness:  -4.923352857176105
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.04709908209307786
# Max roll:  0.00031047351740439935
# Max pitch:  0.00045781026506505764
#
# [6.9381061  4.2835615  2.58529319 5.2033009  6.35606718 1.08322537]
#
# Fitness:  -2.280395830985031
#
#
# Not converged:  False
# Convergence time:  3.8499999999999943
# Target distance:  0.049004688032718235
# Max roll:  0.0007103110594349532
# Max pitch:  0.0004884967496969235
#
# [8.45800406 7.01028051 3.54952366 5.25793076 8.6813048  1.69824378]
#
# Fitness:  -4.890034151110953
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.04478944413933282
# Max roll:  0.00022994024225407326
# Max pitch:  0.0003789891884676603
#
# [8.90077763 5.59699971 2.1084096  6.4437124  9.45194156 1.37637283]
#
# Fitness:  -1.9762353543227433
#
#
# Generation 3: Target at 0.15510204081632656 m
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.04257838477202563
# Max roll:  0.0006769079039595454
# Max pitch:  0.0001995427691034991
#
# [ 9.57002656  3.46723959  2.23257474  7.2768565  11.56190422  1.45040235]
#
# Fitness:  -2.495390229093666
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.04166780675688549
# Max roll:  0.0002457677818386165
# Max pitch:  0.00019437368221117922
#
# [ 9.44036935  5.00220713  2.26542516  5.42654557 10.04743374  1.70913093]
#
# Fitness:  -2.4053632083402006
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.042837937111167436
# Max roll:  0.0007667910230182161
# Max pitch:  0.0003083386174394729
#
# [7.25800977 5.13198068 2.50297218 4.90247078 8.17057394 1.51154518]
#
# Fitness:  -2.660515224246234
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.04190855539522451
# Max roll:  0.0004628387808754567
# Max pitch:  0.0002686634928532117
#
# [10.65291927  6.25317475  1.87943256  6.91209771 11.3136655   1.25327706]
#
# Fitness:  -2.224746221590924
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.041533212506978404
# Max roll:  0.0008849657796708228
# Max pitch:  0.0002616684243221878
#
# [9.53361182 5.26235378 2.76249709 7.34075287 9.11112604 1.31486178]
#
# Fitness:  -2.4379959603392196
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.042310326455053636
# Max roll:  0.0001981331902526615
# Max pitch:  0.00020355068695921996
#
# [10.32059505  6.94147091  2.48795078  6.02231535 10.48362062  1.67961632]
#
# Fitness:  -2.266290722961667
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.04291939681787829
# Max roll:  0.0003915236447843499
# Max pitch:  0.00044025660226493376
#
# [ 6.83103679  4.89593523  3.49693793  5.7162373  10.14049895  1.90552492]
#
# Fitness:  -2.699976948710031
#
#
# Not converged:  False
# Convergence time:  1.5000000000000007
# Target distance:  0.042859724780204556
# Max roll:  0.0008169143997353468
# Max pitch:  0.00019853893069982
#
# [9.93704701 5.92313807 2.58684065 6.30696916 8.26050294 1.12406702]
#
# Fitness:  -2.40796716212585
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.04566814693652518
# Max roll:  0.00037687563913326046
# Max pitch:  0.00025610199847588526
#
# [8.2412106  3.50581243 2.68450453 6.95179918 9.21927388 2.04646741]
#
# Fitness:  -2.6950118206109615
#
#
# Not converged:  False
# Convergence time:  1.5000000000000007
# Target distance:  0.040058713196474215
# Max roll:  0.0005426099252242012
# Max pitch:  0.0007067166366739502
#
# [11.03087998  5.15143366  2.48769171  6.84393293  8.29732024  1.33220433]
#
# Fitness:  -2.3636405920243924
#
#
# Generation 4: Target at 0.17346938775510207 m
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.03759623869437617
# Max roll:  0.0006990614984249475
# Max pitch:  0.0006920656074405713
#
# [ 9.33096037  5.67867563  1.98168542  7.45909907 10.86685262  1.75877067]
#
# Fitness:  -2.5714811291808
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.03818504227007792
# Max roll:  0.0002760657254450744
# Max pitch:  0.00021254316110456734
#
# [10.00270128  6.84452871  1.68777885  7.38633807 13.79336267  1.14756849]
#
# Fitness:  -2.3381312897290414
#
#
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.0357741509320138
# Max roll:  0.0008156588914770793
# Max pitch:  0.0006132261901051463
#
# [ 9.6393875   7.86534924  3.06987259  6.41601196 12.26597611  1.63194906]
#
# Fitness:  -2.386927272719388
#
#
# Not converged:  False
# Convergence time:  1.7000000000000008
# Target distance:  0.035974384525643915
# Max roll:  0.0004993885028740132
# Max pitch:  0.0003771290858181807
#
# [10.07557177  5.62560448  2.16891451  7.09918669 11.06863483  1.50045522]
#
# Fitness:  -2.4633135699474886
#
#
# Not converged:  False
# Convergence time:  1.6500000000000008
# Target distance:  0.03663010294265037
# Max roll:  0.0003849046429943826
# Max pitch:  0.00025150703789700166
#
# [10.94608896  7.83257732  1.91543682  5.11141076  9.22614185  1.69039673]
#
# Fitness:  -2.4144226428975775
#
#
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.03895158134243774
# Max roll:  0.0006606450186335144
# Max pitch:  0.00047940823414412126
#
# [10.8827889   5.46951683  2.0177894   7.38691587 12.10374932  1.46320236]
#
# Fitness:  -2.4360342894876372
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.03885091466811759
# Max roll:  0.000626239236576356
# Max pitch:  0.00040484525011524143
#
# [11.0670126   6.78478754  1.9851625   6.82701031 12.00854315  1.94111886]
#
# Fitness:  -2.3785725176969326
#
#
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.039690373900834235
# Max roll:  0.0005304132764506675
# Max pitch:  0.00025220650495632333
#
# [11.79064587  5.57401144  1.90295847  5.79146011  9.75395718  1.16088451]
#
# Fitness:  -2.4329384670870353
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.03803959656264565
# Max roll:  0.0002506966853781915
# Max pitch:  0.00021120278602734644
#
# [9.74103977 5.33367765 3.00627426 7.22512771 9.16702919 1.51488488]
#
# Fitness:  -2.5838869048231907
#
#
# Not converged:  False
# Convergence time:  1.5500000000000007
# Target distance:  0.037773211885790435
# Max roll:  0.0010239773765240755
# Max pitch:  0.0005549083262199975
#
# [13.05544807  5.04335716  2.28050432  6.40487302 10.96103072  1.50436361]
#
# Fitness:  -2.384408522853013
#
#
# Generation 5: Target at 0.19183673469387758 m
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.030862980798112304
# Max roll:  0.000900409713363718
# Max pitch:  0.0010166056946582134
#
# [10.48508798  7.60611088  1.50124528  7.6965566  11.87988356  1.73751456]
#
# Fitness:  -2.5131103863633433
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.042751342861602336
# Max roll:  0.00047804202736514794
# Max pitch:  0.0003374909627093261
#
# [ 7.97819059  5.29566082  1.6053124   7.86317245 16.65344366  1.11496224]
#
# Fitness:  -2.995803506735771
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.03426438970695091
# Max roll:  0.0006929853257956179
# Max pitch:  0.0003016568806297365
#
# [12.61429993  5.65316569  2.4083395   6.88122682 10.71764832  2.151349  ]
#
# Fitness:  -2.5850199044602866
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.02808321541215267
# Max roll:  0.00036261405687026016
# Max pitch:  0.0009077185654428576
#
# [11.21442053  6.65181818  2.08133845  8.72740242 14.24845504  1.04898639]
#
# Fitness:  -2.37518093935871
#
#
# Not converged:  False
# Convergence time:  2.000000000000001
# Target distance:  0.03498352167470204
# Max roll:  0.0005442654001207117
# Max pitch:  0.0008588260045716734
#
# [11.07165445  5.16887772  2.21346664  6.94402185  9.21191357  2.08147634]
#
# Fitness:  -2.769825003728661
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.03402113453638078
# Max roll:  0.00037807876310324266
# Max pitch:  0.00048443446838694886
#
# [11.54996058  6.45782498  1.65880821  5.62402445 11.58059812  1.34913864]
#
# Fitness:  -2.523548352302126
#
#
# Not converged:  False
# Convergence time:  2.000000000000001
# Target distance:  0.032410657588178224
# Max roll:  0.0007880316479614833
# Max pitch:  0.0008909821157115781
#
# [ 8.99361422  5.96773735  2.18370624  8.05184687 11.22403797  1.5183647 ]
#
# Fitness:  -2.7321638399472183
#
#
# Not converged:  False
# Convergence time:  1.7000000000000008
# Target distance:  0.028590245233348424
# Max roll:  0.0002703873255383132
# Max pitch:  0.00042913832942807577
#
# [12.20628745  8.55131814  1.2683113   6.95638477 11.24397123  0.99735873]
#
# Fitness:  -2.3067811874152886
#
#
# Not converged:  False
# Convergence time:  1.800000000000001
# Target distance:  0.03487645538699678
# Max roll:  0.0003754469575093755
# Max pitch:  0.0005413833000496383
#
# [10.5896508   7.86714427  2.14116792  7.33999661 11.283381    1.95517404]
#
# Fitness:  -2.543370620617887
#
#
# Not converged:  False
# Convergence time:  1.900000000000001
# Target distance:  0.0348519419975649
# Max roll:  0.0010497094898699695
# Max pitch:  0.0005870007546428001
#
# [ 7.80459307  7.0439854   1.45773151  9.16480436 13.58011992  0.89641533]
#
# Fitness:  -2.678874352176938
#
#
# Generation 6: Target at 0.21020408163265308 m
# Not converged:  False
# Convergence time:  1.4500000000000006
# Target distance:  0.03182041858677123
# Max roll:  0.0009049205956562117
# Max pitch:  0.000461295451935336
#
# [13.75393136  5.31531907  2.00527129  7.87672571 11.59051425  1.28776439]
#
# Fitness:  -2.1547191741150025
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.027123846863081263
# Max roll:  0.0005599241737324917
# Max pitch:  0.0006256735609880832
#
# [14.36702964  9.84770548  1.47949902  6.54924709 11.4642685   1.09389888]
#
# Fitness:  -1.9517568239976546
#
#
# Not converged:  False
# Convergence time:  1.5000000000000007
# Target distance:  0.0353513778550288
# Max roll:  0.0006468354738257441
# Max pitch:  0.0004933524821787859
#
# [11.08303153  6.07695979  1.78808896  6.94179752 14.63808534  1.21913776]
#
# Fitness:  -2.264036954900803
#
#
# Not converged:  False
# Convergence time:  1.4500000000000006
# Target distance:  0.03774949854743257
# Max roll:  0.0007643479234299222
# Max pitch:  0.0005891396250693109
#
# [13.04569569  7.1433824   1.35343543  6.29415337  9.36858189  1.22961589]
#
# Fitness:  -2.2726643483736138
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.034690823749072196
# Max roll:  0.0008315479962070171
# Max pitch:  0.0006110037607918977
#
# [13.03882346  6.85744549  1.91429948  9.07569586 15.59301996  1.20830635]
#
# Fitness:  -2.11594406283139
#
#
# Not converged:  False
# Convergence time:  1.5000000000000007
# Target distance:  0.035811387194850414
# Max roll:  0.0009921068772893217
# Max pitch:  0.00034386927798723345
#
# [13.20227813  6.51531476  1.45418767  6.80804831  8.44632672  0.90192167]
#
# Fitness:  -2.2830265516608366
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.03571334439244198
# Max roll:  0.00042602351866358976
# Max pitch:  0.00028420840400239945
#
# [13.14079058  5.39930862  1.97959037  7.47290162 13.62822571  0.8451492 ]
#
# Fitness:  -2.1497784839821397
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.03388586305303761
# Max roll:  0.0007593953612391002
# Max pitch:  0.0003463524468324304
#
# [14.18153531 10.4529779   1.22784753  6.95001724  9.85782259  1.04616671]
#
# Fitness:  -2.083004651464329
#
#
# Not converged:  False
# Convergence time:  1.4500000000000006
# Target distance:  0.03847788717134735
# Max roll:  0.0008630854845566626
# Max pitch:  0.0007189402092453232
#
# [11.68174148  5.57214943  1.98883859  7.10161192 14.64813975  0.89045568]
#
# Fitness:  -2.298659028117047
#
#
# Not converged:  False
# Convergence time:  1.4500000000000006
# Target distance:  0.03270043823035018
# Max roll:  0.0008606829945846988
# Max pitch:  0.0005044656991808168
#
# [10.20524731  9.08442106  1.26856751  8.37790767 11.26217664  1.08921064]
#
# Fitness:  -2.17226619929528
#
#
# Generation 7: Target at 0.2285714285714286 m
# Not converged:  False
# Convergence time:  3.399999999999996
# Target distance:  0.04545141195646945
# Max roll:  0.00032846307681872817
# Max pitch:  0.0005129121725548856
#
# [14.62107174 12.25148139  1.00252548  5.75415537  8.52453742  1.14397218]
#
# Fitness:  -4.351097001598066
#
#
# Not converged:  False
# Convergence time:  3.1999999999999966
# Target distance:  0.04622824778364918
# Max roll:  0.0003558713595655847
# Max pitch:  0.0008290583160049448
#
# [12.54423286  9.52325171  1.4865812   6.7433427   9.75624257  1.26742223]
#
# Fitness:  -4.183811439451507
#
#
# Not converged:  False
# Convergence time:  3.1999999999999966
# Target distance:  0.045676987014703865
# Max roll:  0.000314873260628592
# Max pitch:  0.0007975532788873259
#
# [13.80934474  9.69868367  1.05309429  6.86487151  8.35367136  0.99824261]
#
# Fitness:  -4.16916106726987
#
#
# Not converged:  False
# Convergence time:  2.7499999999999982
# Target distance:  0.042526970458244044
# Max roll:  0.0002475098517417838
# Max pitch:  0.0003026267735077977
#
# [17.36405442  8.30961004  1.56502851  7.65399866 10.20818374  1.02477568]
#
# Fitness:  -3.6280462404273583
#
#
# Not converged:  False
# Convergence time:  2.9999999999999973
# Target distance:  0.04587600526354587
# Max roll:  0.00040095666799985893
# Max pitch:  0.0007156183883017326
#
# [15.28542613  8.15607909  1.51670263  6.86361335  7.98615437  0.91301739]
#
# Fitness:  -3.9733488580859944
#
#
# Not converged:  False
# Convergence time:  2.7499999999999982
# Target distance:  0.04340914037669719
# Max roll:  0.0007854293444976618
# Max pitch:  0.0008614611236838694
#
# [14.97584269  8.97628145  1.58088396  5.70224889 13.53445253  1.11545845]
#
# Fitness:  -3.7005273309430184
#
#
# Not converged:  False
# Convergence time:  2.7499999999999982
# Target distance:  0.043101684574037735
# Max roll:  0.00024149654193863764
# Max pitch:  0.0002638238677027557
#
# [17.45594215  9.90239877  1.4066164   5.6924554  11.78909953  0.98226025]
#
# Fitness:  -3.6372997119628225
#
#
# Not converged:  False
# Convergence time:  2.7499999999999982
# Target distance:  0.04287129535544936
# Max roll:  0.0007069869228267441
# Max pitch:  0.0003248379143235977
#
# [15.71484681  7.3965604   1.55026012  7.07645649 12.39686615  1.34344389]
#
# Fitness:  -3.659017148966502
#
#
# Not converged:  False
# Convergence time:  3.099999999999997
# Target distance:  0.04554578982598244
# Max roll:  0.0007219284381943485
# Max pitch:  0.00045412475493106637
#
# [14.7010835   9.97990078  0.92557051  7.25363202  8.53409578  0.9929165 ]
#
# Fitness:  -4.0697184561759165
#
#
# Not converged:  False
# Convergence time:  2.8999999999999977
# Target distance:  0.0460892005746934
# Max roll:  0.0009531644805783818
# Max pitch:  0.0005775261676431442
#
# [12.75341258 10.3855071   1.31246951  6.35629595 13.44598142  0.88128119]
#
# Fitness:  -3.8983185439049417
#
#
# Generation 8: Target at 0.2469387755102041 m
# Not converged:  False
# Convergence time:  3.7999999999999945
# Target distance:  0.04533993779302584
# Max roll:  0.0002616203354383295
# Max pitch:  0.00040502676397334575
#
# [15.48678111 11.31898287  1.63804163  6.98627709  9.67715268  1.07010663]
#
# Fitness:  -4.740131110831095
#
#
# Not converged:  False
# Convergence time:  3.4499999999999957
# Target distance:  0.04199668074237365
# Max roll:  0.0009580656945384848
# Max pitch:  0.0002502777876662091
#
# [16.23664122  8.05599521  1.08985818  5.96908404 13.17297575  0.83239594]
#
# Fitness:  -4.350350788957703
#
#
# Not converged:  False
# Convergence time:  3.5499999999999954
# Target distance:  0.04654708253156569
# Max roll:  0.0006703273718217471
# Max pitch:  0.0005371215936882343
#
# [21.22516222 10.81589142  1.34636918  8.87344301  8.10943246  1.00722036]
#
# Fitness:  -4.541314098906808
#
#
# Not converged:  False
# Convergence time:  3.4499999999999957
# Target distance:  0.03773413053243956
# Max roll:  0.0011478721244958777
# Max pitch:  0.0005225901181669767
#
# [13.07000138  7.26714829  1.50985474  5.30201737 14.6396926   1.05797958]
#
# Fitness:  -4.28820572278193
#
#
# Not converged:  False
# Convergence time:  3.4499999999999957
# Target distance:  0.04473522413030695
# Max roll:  0.0002672330695282902
# Max pitch:  0.00025024987834462194
#
# [17.52579862  8.3766422   1.56600097  7.03525723 12.08890886  1.05892638]
#
# Fitness:  -4.37057862999978
#
#
# Not converged:  False
# Convergence time:  3.599999999999995
# Target distance:  0.0460801358673812
# Max roll:  0.0005034557092624192
# Max pitch:  0.0002598566257243289
#
# [13.29006581  6.29685543  1.65992042  7.05300099 11.50940205  1.00719941]
#
# Fitness:  -4.559768334096956
#
#
# Not converged:  False
# Convergence time:  3.999999999999994
# Target distance:  0.0437528124083273
# Max roll:  0.00047861454456410207
# Max pitch:  0.0003370299244229975
#
# [17.13313263 12.28488127  1.55237837  6.17175517  8.03500349  1.15920552]
#
# Fitness:  -4.915838471615894
#
#
# Not converged:  False
# Convergence time:  3.649999999999995
# Target distance:  0.04267055454480912
# Max roll:  0.0008083240693398669
# Max pitch:  0.00046172700961958664
#
# [17.69435794  7.99749536  1.67015584  5.21337378 10.73373633  1.06729592]
#
# Fitness:  -4.56691364484415
#
#
# Not converged:  False
# Convergence time:  3.2999999999999963
# Target distance:  0.04412905262754684
# Max roll:  0.00043114821990091823
# Max pitch:  0.0002507067182606355
#
# [21.56437691 12.18130162  1.31395647  9.43695306 12.03393285  1.07565878]
#
# Fitness:  -4.21667379945901
#
#
# Not converged:  False
# Convergence time:  3.4999999999999956
# Target distance:  0.04295679702831621
# Max roll:  0.0007664628892292887
# Max pitch:  0.00040583811821435383
#
# [20.09481203  6.29176689  1.50262808  5.31482964 11.46048402  1.10013069]
#
# Fitness:  -4.417750990938502
#
#
# Generation 9: Target at 0.2653061224489796 m
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.023316122777460445
# Max roll:  0.0003166901137446599
# Max pitch:  0.00027956109286145784
#
# [12.83504219  9.0492497   1.58778202  5.09498156 16.83845972  1.31406   ]
#
# Fitness:  -1.4461350158795152
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.03437377167361469
# Max roll:  0.0001593526141225008
# Max pitch:  0.00023613076749283692
#
# [24.69459923 10.16866338  1.21693137  9.3044895   9.65562958  1.22568809]
#
# Fitness:  -1.7072496025530608
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.02705449456776993
# Max roll:  0.0003051204601373499
# Max pitch:  0.00028529424200335367
#
# [14.5225249   7.8361914   1.2914292   5.47968192 12.38914597  1.01931644]
#
# Fitness:  -1.6206106264624343
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.02756635140245207
# Max roll:  0.0002577606586590098
# Max pitch:  0.0002773741149227513
#
# [19.21318247 11.68824138  1.32138011  8.13744619 11.3582366   1.09751363]
#
# Fitness:  -1.5780837667281298
#
#
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.02245092256163665
# Max roll:  0.00016833356941381173
# Max pitch:  0.0002649218591558094
#
# [13.99914312  7.57469327  1.25056217  5.39414262 16.50947796  1.14789575]
#
# Fitness:  -1.4206812226612142
#
#
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.01866777938122546
# Max roll:  0.0005737305950432478
# Max pitch:  0.0004505852314264348
#
# [18.33291386 14.10909883  1.11122225  7.85145844 14.01051445  1.01054891]
#
# Fitness:  -1.3745713789479936
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.024061689146282077
# Max roll:  0.00031936710992561736
# Max pitch:  0.0008701185615800978
#
# [12.72785115  6.72144272  1.73000693  5.0790422  13.61053928  1.09185368]
#
# Fitness:  -1.5907080665009277
#
#
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.023619086046368278
# Max roll:  0.0007438054662733397
# Max pitch:  0.0007456014167764416
#
# [23.91501527 14.50287417  1.28839499 10.24967289 11.8014304   1.17215103]
#
# Fitness:  -1.4968520650798551
#
#
# Not converged:  False
# Convergence time:  1.1500000000000004
# Target distance:  0.022809634054912303
# Max roll:  0.0003782158755806135
# Max pitch:  0.0004475350993959306
#
# [15.64796773  7.49632853  1.19077652  4.55775488 11.08786917  1.01104788]
#
# Fitness:  -1.6474802298470737
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.03044929987860677
# Max roll:  0.0005354721959453734
# Max pitch:  0.0006278502356510669
#
# [25.52010771 10.64688161  1.20195024  7.43556313 10.05391488  1.12046491]
#
# Fitness:  -1.7171521191519576
#
#
# Generation 10: Target at 0.2836734693877551 m
# Not converged:  False
# Convergence time:  1.2500000000000004
# Target distance:  0.014891016209733262
# Max roll:  0.0007899893309564634
# Max pitch:  0.0006667358506708496
#
# [16.76814561  9.45588572  1.53090708  5.23595573 17.95262768  1.21511315]
#
# Fitness:  -1.6206565832760313
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.008611394220045709
# Max roll:  0.0005091406311803655
# Max pitch:  0.00023901284230971496
#
# [16.38570558 16.42025224  0.91125404  6.31683936 16.25716087  1.16412447]
#
# Fitness:  -1.4096355580754187
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.026732725892124463
# Max roll:  0.0006293964115372335
# Max pitch:  0.0008136152838133901
#
# [12.89055358  8.69385501  1.43748509  6.33699418 16.39180001  1.25497972]
#
# Fitness:  -2.0068051026100213
#
#
# Not converged:  False
# Convergence time:  1.2500000000000004
# Target distance:  0.011645207928887277
# Max roll:  0.0003753041332647608
# Max pitch:  0.00026493397296608684
#
# [17.80364584 10.88894318  0.85646568  8.13696312 14.21879732  0.97634121]
#
# Fitness:  -1.5149160638892885
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.011812554061226136
# Max roll:  0.000832178045398959
# Max pitch:  0.000643424817321352
#
# [15.5900983   9.25973504  1.11519024  6.14383932 14.37768328  1.00564136]
#
# Fitness:  -1.6600312243605386
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.01993243388010741
# Max roll:  0.0008837750040892999
# Max pitch:  0.0002812065562259585
#
# [22.61127954 14.0799254   1.22694739  9.08656761 12.30340563  0.98668052]
#
# Fitness:  -1.6568977556179112
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.019228069523649034
# Max roll:  0.0008190813821127464
# Max pitch:  0.0005904348057435992
#
# [14.99157418  7.67602031  1.02250215  5.03038078 15.35681222  1.25107436]
#
# Fitness:  -1.8050371998657986
#
#
# Not converged:  False
# Convergence time:  1.2500000000000004
# Target distance:  0.008919075801341858
# Max roll:  0.0006678478712077345
# Max pitch:  0.000330918452775721
#
# [19.74768359 13.64625391  1.31198815  7.62808555 13.64020908  1.02541056]
#
# Fitness:  -1.4783198322260105
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.026934689663790177
# Max roll:  0.0005509298804516332
# Max pitch:  0.000223454688021135
#
# [14.72114017  6.61679123  1.25434492  4.40639962 17.29718311  1.33391492]
#
# Fitness:  -1.9274130216994425
#
#
# Not converged:  False
# Convergence time:  1.1500000000000004
# Target distance:  0.014121279155282341
# Max roll:  0.0009455446679468674
# Max pitch:  0.00042275548755265767
#
# [21.83350554 16.52972156  0.97518737  7.83182879 14.89713022  0.91017145]
#
# Fitness:  -1.5008405908806235
#
#
# Generation 11: Target at 0.3020408163265306 m
# Not converged:  False
# Convergence time:  1.1000000000000003
# Target distance:  0.009261077667715336
# Max roll:  0.00044493345671015966
# Max pitch:  0.0004911487026881196
#
# [16.02999264 17.00020875  1.20585627  7.7597733  13.27188276  1.03354604]
#
# Fitness:  -1.332025661324221
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.013581259124060049
# Max roll:  0.0007825636708537082
# Max pitch:  0.00023886399095220852
#
# [15.10933576 13.49601899  0.79710993  6.16145904 16.0750545   1.02202372]
#
# Fitness:  -1.372696565571497
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.008669028613708028
# Max roll:  0.0010591967761615572
# Max pitch:  0.00048035394963753103
#
# [23.26105659 10.56566484  1.33314786  5.76507387 16.86713597  1.17992436]
#
# Fitness:  -1.2503581085641153
#
#
# Not converged:  False
# Convergence time:  1.1500000000000004
# Target distance:  0.01821699558643388
# Max roll:  0.0007679217012556628
# Max pitch:  0.0006301877073288731
#
# [13.77045273 13.2302238   1.04893808  4.8841221  13.00803216  1.20407782]
#
# Fitness:  -1.5842453821579048
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.009714636591802836
# Max roll:  0.0002567241231957947
# Max pitch:  0.0002594602203611121
#
# [20.28565298 16.4722142   1.62935195  9.42360326 15.10926897  0.86625119]
#
# Fitness:  -1.2201019490139025
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.015876542306707143
# Max roll:  0.0005827652087599559
# Max pitch:  0.00024230490310376927
#
# [12.53709084 18.91698327  0.78407664  5.70751062 18.14672947  1.20190637]
#
# Fitness:  -1.4087843517273293
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.012117614677966314
# Max roll:  0.0009090550617716507
# Max pitch:  0.0006205141965100824
#
# [23.42364294 13.66835531  1.32837388  8.11396477 13.58316594  1.10711017]
#
# Fitness:  -1.368830756473413
#
#
# Not converged:  False
# Convergence time:  1.1500000000000004
# Target distance:  0.014946720133583925
# Max roll:  0.00031440683081200197
# Max pitch:  0.00023256923460183336
#
# [14.03079609 13.94712356  0.74576684  6.50755114 12.42184637  1.04682674]
#
# Fitness:  -1.4762832059423707
#
#
# Not converged:  False
# Convergence time:  1.1000000000000003
# Target distance:  0.01509483864273911
# Max roll:  0.00024614971172765026
# Max pitch:  0.0002528383292666154
#
# [15.25748065 12.08123057  1.12522049  6.42043861 14.33637301  0.98463515]
#
# Fitness:  -1.4268461749044956
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.020679164068026543
# Max roll:  0.0002620039964141662
# Max pitch:  0.0002395113533241104
#
# [12.73984362 19.16053431  0.86875189  7.44779199 19.10487782  0.95097007]
#
# Fitness:  -1.4386590488474449
#
#
# Generation 12: Target at 0.3204081632653062 m
# Not converged:  False
# Convergence time:  1.6000000000000008
# Target distance:  0.020866277191262234
# Max roll:  0.0002589320970990381
# Max pitch:  0.00025985801748604095
#
# [27.11608688  8.48409097  1.36087537  5.02751312 20.65122351  1.19952948]
#
# Fitness:  -2.043265049554499
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.043162962184221394
# Max roll:  0.0008291094656595635
# Max pitch:  0.0005773167706228926
#
# [21.74713723 18.34205595  1.57572172 10.62835561 13.39675469  0.74484503]
#
# Fitness:  -2.7835805554985518
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.02576118407002259
# Max roll:  0.00026909484111606443
# Max pitch:  0.00033982698256472364
#
# [18.4748953   9.5506279   1.03387927  5.16321455 15.6697347   0.94526028]
#
# Fitness:  -2.395669772584492
#
#
# Not converged:  False
# Convergence time:  4.249999999999993
# Target distance:  0.011693567474308787
# Max roll:  0.0009006261077768336
# Max pitch:  0.00046260462978672795
#
# [15.56980639 17.03601958  1.91391302  8.54382704 13.55741734  0.8768201 ]
#
# Fitness:  -4.552032886364347
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.024059652945650416
# Max roll:  0.0006584218711810863
# Max pitch:  0.0006899042664473066
#
# [25.26341209 10.92689639  1.54612168  5.3259725  14.7853815   1.31897836]
#
# Fitness:  -2.298609365794429
#
#
# Not converged:  False
# Convergence time:  3.5499999999999954
# Target distance:  0.020202324808645134
# Max roll:  0.0007494910438537121
# Max pitch:  0.0005115176705728259
#
# [20.10358658 19.49222321  1.31143057 10.42078805 16.61026968  0.91721598]
#
# Fitness:  -4.017096931894225
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.01634620521914594
# Max roll:  0.00024451864407324563
# Max pitch:  0.0002827199122761477
#
# [23.37821562  8.22627339  1.65150822  5.88808047 13.3811375   1.16759221]
#
# Fitness:  -2.2032860322003893
#
#
# Not converged:  False
# Convergence time:  1.850000000000001
# Target distance:  0.03943209253420362
# Max roll:  0.0008934127677552589
# Max pitch:  0.00029456469285262546
#
# [24.57688996 13.62333853  1.35457312 11.65473591 14.64020028  0.87820139]
#
# Fitness:  -2.6980407237144677
#
#
# Not converged:  False
# Convergence time:  1.6500000000000008
# Target distance:  0.020602517790661214
# Max roll:  0.000737930942143441
# Max pitch:  0.0003474500803353393
#
# [28.22509582 11.18983648  1.47343285  5.13310588 16.65428958  1.15452649]
#
# Fitness:  -2.1163194069371642
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.037042860852504716
# Max roll:  0.0006636953114824009
# Max pitch:  0.0007823639342987841
#
# [19.63935416 15.8384619   1.43756117 11.02244508 15.67790361  1.0414362 ]
#
# Fitness:  -2.5631601793391545
#
#
# Generation 13: Target at 0.3387755102040817 m
# Not converged:  False
# Convergence time:  0.9000000000000002
# Target distance:  0.020632675639393125
# Max roll:  0.00018389379897073107
# Max pitch:  0.0002478490781404972
#
# [22.07534619  8.60391085  1.67824318  4.85662357 20.29563248  1.4378831 ]
#
# Fitness:  -1.334240656643424
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.011115062044361886
# Max roll:  0.00013398184310242127
# Max pitch:  0.00031276491440763434
#
# [33.35395506 10.32107329  1.12558743  4.47043272 16.36961864  1.28289278]
#
# Fitness:  -1.2446385787627408
#
#
# Not converged:  False
# Convergence time:  1.0500000000000003
# Target distance:  0.0045077256644234795
# Max roll:  0.0005709116977657803
# Max pitch:  0.0010322467670639585
#
# [26.48678352 12.63528655  1.13243551  4.33315019 14.27220171  1.43444206]
#
# Fitness:  -1.2203124365299567
#
#
# Not converged:  False
# Convergence time:  0.8500000000000002
# Target distance:  0.03284989540726355
# Max roll:  0.000787033209194764
# Max pitch:  0.0006613469084415472
#
# [27.60220338  8.41865489  1.1139201   5.46577978 22.46876631  1.26631456]
#
# Fitness:  -1.5794169140270866
#
#
# Not converged:  False
# Convergence time:  0.9000000000000002
# Target distance:  0.029373189278876746
# Max roll:  0.0005833748664100847
# Max pitch:  0.0005816292483314634
#
# [30.53579121 10.27178923  1.27974856  5.93101903 19.73254687  0.96741253]
#
# Fitness:  -1.5457139913146125
#
#
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.02856894761252497
# Max roll:  0.0006029895387978588
# Max pitch:  0.000889212977055453
#
# [33.00645862  8.34202153  1.14043009  5.01848563 19.17477578  1.34657669]
#
# Fitness:  -1.5959890780431651
#
#
# Not converged:  False
# Convergence time:  1.0000000000000002
# Target distance:  0.00289851700185209
# Max roll:  0.0005475168043141353
# Max pitch:  0.0008137908735706356
#
# [24.82505533 11.94513271  1.26033101  4.78475617 15.48727147  1.2317488 ]
#
# Fitness:  -1.1260357239312804
#
#
# Not converged:  False
# Convergence time:  0.9500000000000003
# Target distance:  0.024828947516559858
# Max roll:  0.00022854931273503823
# Max pitch:  0.00024783174452244197
#
# [23.56226312  9.53819806  1.23861631  5.21734218 18.50890413  1.17402875]
#
# Fitness:  -1.4703980031940713
#
#
# Not converged:  False
# Convergence time:  0.9000000000000002
# Target distance:  0.029001500513082475
# Max roll:  0.0006668034343597387
# Max pitch:  0.0006276652412837794
#
# [28.96893728 10.09153302  1.42965925  5.50388239 19.85786351  0.96128306]
#
# Fitness:  -1.5447534440438255
#
#
# Not converged:  False
# Convergence time:  0.9000000000000002
# Target distance:  0.04042720408218856
# Max roll:  0.000511110199452427
# Max pitch:  0.00030046271042529047
#
# [23.95233189  8.86592886  1.61014109  6.04184143 21.64484797  1.34509738]
#
# Fitness:  -1.7491227271376573
#
#
# Generation 14: Target at 0.3571428571428572 m
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.01558967030904735
# Max roll:  0.0002596758715137039
# Max pitch:  0.0002468070451964098
#
# [24.49956019 12.00984616  1.27020041  4.30114425 10.97444591  1.33968944]
#
# Fitness:  -1.7371175520164532
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.028989355876611417
# Max roll:  0.0006291424502199878
# Max pitch:  0.0002347504114321018
#
# [24.12232366 11.31192988  1.05887367  4.3868898  17.32676882  1.00140634]
#
# Fitness:  -1.822981760614833
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.01547511245228017
# Max roll:  0.0002614103809034977
# Max pitch:  0.0002560214723284474
#
# [32.33081526 15.12778124  1.27930743  3.33421447 11.98556432  1.42373979]
#
# Fitness:  -1.7353738417072013
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.016771153879039085
# Max roll:  0.0009579973519853586
# Max pitch:  0.00034666516817822917
#
# [27.19126787 14.43750496  1.0608834   4.72117237 15.61283147  1.15500297]
#
# Fitness:  -1.6006562035889613
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.017396649303491888
# Max roll:  0.0008335198224515613
# Max pitch:  0.00023049907331384575
#
# [21.45120293 14.30786303  1.19148575  3.27500475 14.22483645  1.77834692]
#
# Fitness:  -1.7511339308581086
#
#
# Not converged:  False
# Convergence time:  1.2500000000000004
# Target distance:  0.008917092221972156
# Max roll:  0.0010141019758088566
# Max pitch:  0.00030166943949264173
#
# [25.05955629 13.05636687  1.50371652  5.54493219 14.01929033  1.31483969]
#
# Fitness:  -1.4941304152045185
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.00998435978673329
# Max roll:  0.0010025383654772785
# Max pitch:  0.00025313770695339845
#
# [30.06825449 11.0969285   1.24537447  4.93840147 12.65107615  1.49028827]
#
# Fitness:  -1.5624709993562
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.030786284662057285
# Max roll:  0.000590782299840686
# Max pitch:  0.0002879698420711882
#
# [27.37863483 12.89339268  1.34433082  5.09371575 16.57288599  0.93453303]
#
# Fitness:  -1.8596633003367398
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.012415008786123454
# Max roll:  0.00045142464665779027
# Max pitch:  0.00027565309701015934
#
# [24.34088696  9.83994475  1.24596216  3.92391415 10.94828121  1.14423394]
#
# Fitness:  -1.6846540629058673
#
#
# Not converged:  False
# Convergence time:  1.2000000000000004
# Target distance:  0.027576207364723247
# Max roll:  0.0006113786549751586
# Max pitch:  0.0002483953846154064
#
# [27.22151381  9.08597349  1.52761809  4.75919915 17.9350612   1.47766448]
#
# Fitness:  -1.7945128492739937
#
#
# Generation 15: Target at 0.3755102040816327 m
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.022969657165132825
# Max roll:  0.0005856687135555733
# Max pitch:  0.00026169245788553195
#
# [31.07164459 11.14964901  1.34405949  4.74333765 14.06587937  1.30553186]
#
# Fitness:  -1.8517612018747125
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.01332989464743555
# Max roll:  0.00026135625344200395
# Max pitch:  0.00027836733982755196
#
# [30.64022531 13.31059785  1.68679994  5.69700381 12.49727073  1.28252468]
#
# Fitness:  -1.6435840726121893
#
#
# Not converged:  False
# Convergence time:  1.3500000000000005
# Target distance:  0.03214389503650715
# Max roll:  0.000997151232613162
# Max pitch:  0.00024690412675253744
#
# [26.60322013 11.15232193  1.36485168  3.94679944 15.36822958  1.38575401]
#
# Fitness:  -2.0550806686984284
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.0163589537299327
# Max roll:  0.000812073744869106
# Max pitch:  0.00032617787684434315
#
# [22.33135854 12.87486138  1.5943293   5.2237484  15.82880687  1.54773683]
#
# Fitness:  -1.6840916556843268
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.019989945126962005
# Max roll:  0.0005847229473320352
# Max pitch:  0.00025940151234620586
#
# [30.94138413 11.87946391  1.54889425  4.64720647 13.17886578  1.49964404]
#
# Fitness:  -1.8420051255231529
#
#
# Not converged:  False
# Convergence time:  1.4500000000000006
# Target distance:  0.02187505481026702
# Max roll:  0.0007143657555749181
# Max pitch:  0.00027971354136448456
#
# [27.14372221 15.54723068  1.13327538  5.44009182 10.98467975  1.59300312]
#
# Fitness:  -1.9372050610523113
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.01689149915303298
# Max roll:  0.0007728228393551993
# Max pitch:  0.0002903096057805006
#
# [29.11101422 12.26379722  1.42757053  4.64800388 14.74859044  1.42004905]
#
# Fitness:  -1.690986605317445
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.014509790540299506
# Max roll:  0.0010475722857562926
# Max pitch:  0.00041384869262336857
#
# [21.36345654 11.3669981   1.55582446  4.73317791 13.58382504  1.40337817]
#
# Fitness:  -1.7632668597249737
#
#
# Not converged:  False
# Convergence time:  1.3000000000000005
# Target distance:  0.013866812117321508
# Max roll:  0.0010209988029994332
# Max pitch:  0.00035029969931205503
#
# [27.62219923  9.36684527  1.4323615   4.72559996 15.80512977  1.79717945]
#
# Fitness:  -1.645901167462005
#
#
# Not converged:  False
# Convergence time:  1.4000000000000006
# Target distance:  0.012994177229266638
# Max roll:  0.00028839549581116686
# Max pitch:  0.00024818147813115586
#
# [22.19116492 10.23247216  1.68192     6.16775491 12.63895852  0.9982466 ]
#
# Fitness:  -1.6867123932824495
#
#
# Generation 16: Target at 0.3938775510204082 m
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.025484212777109102
# Max roll:  0.0009111600939999716
# Max pitch:  0.0005898818921821535
#
# [22.69126918  7.74472134  1.07756685  4.11011012 15.73340093  1.86755751]
#
# Fitness:  -2.334736354851289
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.02379140776611743
# Max roll:  0.0011467577122499493
# Max pitch:  0.00045187240577093397
#
# [31.90683736 12.47010731  2.0208998   5.45784978 12.36811337  1.54378608]
#
# Fitness:  -2.305759661223394
#
#
# Not converged:  False
# Convergence time:  1.7000000000000008
# Target distance:  0.04072010114782916
# Max roll:  0.0009031096166426037
# Max pitch:  0.0007294303896122623
#
# [23.97049566  9.67385592  1.49236624  4.30562166 16.92444684  1.72218837]
#
# Fitness:  -2.5960290232693275
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.25569632591269686
# Max roll:  3.14159265352034
# Max pitch:  0.8551369510495868
#
# [29.14375329 14.21098661  1.73234788  6.48323395 15.43165216  1.045783  ]
#
# Fitness:  -249.95040674675025
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.36281668432669983
# Max roll:  3.141592653570732
# Max pitch:  0.8617528183473864
#
# [33.32737086  9.74668291  1.29428114  5.63701656 18.19329558  2.21322582]
#
# Fitness:  -252.42360728243992
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.16302283994289304
# Max roll:  3.1415926535863243
# Max pitch:  1.2612106327313826
#
# [37.59081358 15.70716852  1.5387253   4.83482695 15.333909    1.25966802]
#
# Fitness:  -268.4006211147432
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.015209235775012443
# Max roll:  0.0006161466717655957
# Max pitch:  0.0007578076579823147
#
# [24.71154779  7.536658    1.61297628  4.98335773 14.48719306  2.06169   ]
#
# Fitness:  -2.1228824319876454
#
#
# Not converged:  False
# Convergence time:  1.7500000000000009
# Target distance:  0.024612215188875568
# Max roll:  0.0004398935038964837
# Max pitch:  0.0004742798014318916
#
# [30.76830649 11.00170657  1.51123214  5.93980782 11.90545898  1.28103321]
#
# Fitness:  -2.287952969043931
#
#
# Not converged:  False
# Convergence time:  1.7000000000000008
# Target distance:  0.021592416637452466
# Max roll:  0.0007719801370635931
# Max pitch:  0.0005327145140361907
#
# [30.10751624  7.93928262  1.51240374  4.43175439 14.40196153  1.77874218]
#
# Fitness:  -2.1970830653040396
#
#
# Not converged:  False
# Convergence time:  1.950000000000001
# Target distance:  0.023590311571111282
# Max roll:  0.0005497326814976502
# Max pitch:  0.0003105035252007463
#
# [28.59578168 11.79333384  1.35717135  4.27896211  9.48272335  1.50109276]
#
# Fitness:  -2.464818041757147
#
#
# Generation 17: Target at 0.41224489795918373 m
# Not converged:  False
# Convergence time:  2.7499999999999982
# Target distance:  0.0400224438213425
# Max roll:  0.00046648081557438306
# Max pitch:  0.0009583707591298407
#
# [24.09424399  8.70330364  1.14742119  4.63277533 17.2270803   1.55303389]
#
# Fitness:  -3.6216914551620594
#
#
# Not converged:  False
# Convergence time:  2.8999999999999977
# Target distance:  0.03271557096476462
# Max roll:  0.0002632149425231819
# Max pitch:  0.00043599046376311865
#
# [21.6330234   7.76449305  1.32763477  5.16647849 14.5275403   2.28499894]
#
# Fitness:  -3.5892716896096055
#
#
# Not converged:  False
# Convergence time:  2.6499999999999986
# Target distance:  0.0215552267438509
# Max roll:  0.0006335323214695992
# Max pitch:  0.0008214591212763127
#
# [31.13359055  9.8354905   1.84273832  3.86293296 12.99240145  2.00153849]
#
# ...
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.03342290811028229
# Max roll:  0.0008148831242947125
# Max pitch:  0.0008574851961692135
#
# [43.74401255  3.46143979  4.34105678  5.44669357  3.84375093  0.74571245]
#
# Fitness:  -2.8520765782288424
#
#
# Not converged:  False
# Convergence time:  2.3999999999999995
# Target distance:  0.00304024578191409
# Max roll:  0.0005559432396766666
# Max pitch:  0.0004670281906599463
#
# [27.60568559  2.02455     4.2695413   4.97082805  2.76827107  0.65827423]
#
# Fitness:  -2.511953487155112
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.40636685987393567
# Max roll:  3.141592652606973
# Max pitch:  1.1937468279752599
#
# [47.73197998  2.60609244  5.26822853  5.80843147  4.66406942  0.81224912]
#
# Fitness:  -269.89431122659033
#
#
# Not converged:  False
# Convergence time:  2.25
# Target distance:  0.007269105897568346
# Max roll:  0.0005584811993460012
# Max pitch:  0.00030672560914351004
#
# [43.31621955  2.51063896  5.06720411  5.60887934  3.07108672  0.83491688]
#
# Fitness:  -2.438642458375843
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.5006248588700293
# Max roll:  3.1415926431455565
# Max pitch:  0.6600109171312887
#
# [31.96063171  2.79316539  5.02545223  3.67124078  4.22871691  0.68376708]
#
# Fitness:  -245.09267519124282
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.021423951174933994
# Max roll:  0.00061639392735783
# Max pitch:  0.00043961241919636624
#
# [42.85393339  2.21069936  3.68249751  5.74943665  3.69053475  0.82237168]
#
# Fitness:  -2.58127934082639
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.045053137234875126
# Max roll:  0.0005198186055281017
# Max pitch:  0.0005233526943519611
#
# [32.45218137  4.04250381  4.72113063  4.10511     4.28989705  0.79710627]
#
# Fitness:  -3.053221309691506
#
#
# Not converged:  False
# Convergence time:  2.25
# Target distance:  0.014957856900240244
# Max roll:  0.0004887223561006934
# Max pitch:  0.00046363127875207393
#
# [41.70560615  2.44416684  4.46818794  5.40589352  3.19285049  0.82577221]
#
# Fitness:  -2.5967748197474436
#
#
# Not converged:  False
# Convergence time:  2.2
# Target distance:  0.012790600443007711
# Max roll:  0.0008667035155384584
# Max pitch:  0.0007494602519917002
#
# [42.15206606  3.76783431  4.12181279  4.95116057  3.32084997  0.66223297]
#
# Fitness:  -2.5366201972366618
#
#
# Generation 45: Target at 0.926530612244898 m
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.023053579325305728
# Max roll:  0.0002530263721690166
# Max pitch:  0.0008069478844683717
#
# [26.78886155  1.60690777  3.28172327  6.02744101  3.380284    0.53978092]
#
# Fitness:  -2.614070299337984
#
#
# Not converged:  False
# Convergence time:  2.25
# Target distance:  0.016444694878699533
# Max roll:  0.00026126554808542345
# Max pitch:  0.0003490225285467531
#
# [47.7816084   2.20124546  4.32004808  4.80091445  3.03827796  0.75602684]
#
# Fitness:  -2.6094083014055998
#
#
# Not converged:  False
# Convergence time:  2.3
# Target distance:  0.004136984766594087
# Max roll:  0.0004198512878064325
# Max pitch:  0.0006096083590402063
#
# [23.71436846  2.06233086  4.92812576  4.88416042  2.874274    0.73734804]
#
# Fitness:  -2.4342126776742132
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.040749842431176866
# Max roll:  0.0005952618524432054
# Max pitch:  0.0006559596662519525
#
# [37.03665898  2.80490108  5.68115911  4.75083833  3.81690033  0.81522035]
#
# Fitness:  -2.9775579245582957
#
#
# Not converged:  False
# Convergence time:  2.6499999999999986
# Target distance:  0.00561029519216157
# Max roll:  0.0005657988287651903
# Max pitch:  0.0008837682220021475
#
# [31.37371454  2.30440717  5.14637201  4.14809582  2.07873972  0.54487581]
#
# Fitness:  -2.8346842563815966
#
#
# Not converged:  False
# Convergence time:  2.1500000000000004
# Target distance:  0.0036012549226485655
# Max roll:  0.0003966764599562579
# Max pitch:  0.0003940581034091117
#
# [45.1530325   2.37665011  5.80760271  5.98202182  3.00100565  0.80601043]
#
# Fitness:  -2.26156182662124
#
#
# Not converged:  False
# Convergence time:  2.3999999999999995
# Target distance:  0.014539349399947197
# Max roll:  0.00055926546321848
# Max pitch:  0.0005063701449443336
#
# [25.3060139   1.87195544  3.26089912  6.17366188  2.17316752  0.70908919]
#
# Fitness:  -2.7440687684070837
#
#
# Not converged:  False
# Convergence time:  2.1000000000000005
# Target distance:  0.03426654224382168
# Max roll:  0.0005509803530282191
# Max pitch:  0.0008009504630734468
#
# [49.99473732  3.07547895  5.1576316   4.95482428  3.69365356  0.85884538]
#
# Fitness:  -2.8529273856815176
#
#
# Not converged:  False
# Convergence time:  2.2
# Target distance:  0.01562936025361493
# Max roll:  0.0002507158843410754
# Max pitch:  0.0006713757867921799
#
# [25.24794987  2.25015656  5.11522071  4.97342372  3.16060753  0.53944637]
#
# Fitness:  -2.5586917886289613
#
#
# Not converged:  False
# Convergence time:  2.1500000000000004
# Target distance:  0.0022462014460240738
# Max roll:  0.0006702621799294053
# Max pitch:  0.0007287941353760987
#
# [42.89822166  2.82936161  4.23518414  6.89925329  2.86728097  0.9480087 ]
#
# Fitness:  -2.264876844685757
#
#
# Generation 46: Target at 0.9448979591836735 m
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.5405146694496784
# Max roll:  3.141592653571971
# Max pitch:  0.9904185143517067
#
# [45.62319168  2.87721686  4.55855408  8.5424235   2.15215747  1.12904986]
#
# Fitness:  -262.41085178517744
#
#
# Not converged:  False
# Convergence time:  2.2
# Target distance:  0.017047207788344038
# Max roll:  0.0005597833033223911
# Max pitch:  0.0005781788413429782
#
# [51.66399313  2.73763577  4.96667941  5.0218318   3.32665242  0.85787286]
#
# Fitness:  -2.5978422630001496
#
#
# Not converged:  False
# Convergence time:  2.3999999999999995
# Target distance:  0.013240903814951402
# Max roll:  0.000578707201303489
# Max pitch:  0.0005968851826242783
#
# [51.07720812  2.8881607   4.64867653  7.20777492  2.19094074  0.80495628]
#
# Fitness:  -2.7235976954954157
#
#
# Not converged:  False
# Convergence time:  2.3499999999999996
# Target distance:  0.004833180230264694
# Max roll:  0.00043792490590730465
# Max pitch:  0.00028649765649851693
#
# [35.7763856   1.92817627  6.35469127  6.16961574  2.59324001  0.89837679]
#
# Fitness:  -2.4828847327255845
#
#
# Not converged:  False
# Convergence time:  2.3999999999999995
# Target distance:  0.007317508293089729
# Max roll:  0.0007427471327981938
# Max pitch:  0.0005759339578615304
#
# [52.7905887   2.68613664  5.22522613  6.36183361  2.320262    0.87404247]
#
# Fitness:  -2.61228422039478
#
#
# Not converged:  False
# Convergence time:  2.2
# Target distance:  0.0331864837851611
# Max roll:  0.0008737760865862466
# Max pitch:  0.0005907118050986644
#
# [39.14936892  2.32917206  5.80249769  5.22901612  3.4965      0.7461871 ]
#
# Fitness:  -2.9369540702874675
#
#
# Not converged:  False
# Convergence time:  2.4499999999999993
# Target distance:  0.00970558224186694
# Max roll:  0.0006571658548361657
# Max pitch:  0.00041798180565052475
#
# [34.39696705  3.0136924   5.0312321   6.80588172  2.21921307  1.00677723]
#
# Fitness:  -2.697869027861673
#
#
# Not converged:  False
# Convergence time:  2.1500000000000004
# Target distance:  0.01615770994885049
# Max roll:  0.00096750496912352
# Max pitch:  0.0011940614821530054
#
# [44.01658886  2.8858621   6.3496727   6.40459324  3.22705659  0.67379245]
#
# Fitness:  -2.5812325215408363
#
#
# Not converged:  False
# Convergence time:  2.3999999999999995
# Target distance:  0.0024651244416809804
# Max roll:  0.0007798301874707757
# Max pitch:  0.00104004061217777
#
# [49.42127316  2.49471756  5.26008863  6.17563526  2.50608854  1.12493418]
#
# Fitness:  -2.5402960288160465
#
#
# Not converged:  False
# Convergence time:  2.1500000000000004
# Target distance:  0.04313362788474859
# Max roll:  0.00037222168543163566
# Max pitch:  0.0002689830029676668
#
# [50.63328979  2.70284194  5.10769977  4.67520287  3.73838572  0.68663418]
#
# Fitness:  -3.0447327921149374
#
#
# Generation 47: Target at 0.963265306122449 m
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.8299507924362687
# Max roll:  3.1415926534071694
# Max pitch:  0.8345680682592458
#
# [40.20844745  1.98536999  5.89313142  5.53092279  1.9582082   1.24067258]
#
# Fitness:  -260.40705193204616
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7585471901579429
# Max roll:  3.141592652974767
# Max pitch:  1.0593801858875533
#
# [43.11151585  1.76958485  5.68092665  6.32569163  1.97901991  1.00803071]
#
# Fitness:  -270.21958574627484
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.74785290339249
# Max roll:  3.141592652809727
# Max pitch:  1.480087965923059
#
# [47.09136752  2.48168914  5.94437842  6.76645476  2.14422453  1.04723981]
#
# Fitness:  -291.0410890044891
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7910702686501663
# Max roll:  3.141592653573403
# Max pitch:  1.299376296244124
#
# [34.12117519  2.4037958   7.89726673  5.42402994  2.24202315  0.833427  ]
#
# Fitness:  -282.8698528638797
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7739314082411037
# Max roll:  3.141592653038869
# Max pitch:  0.36080454823577973
#
# [48.78538776  2.0484985   5.00446297  4.85443457  2.67141675  0.98826669]
#
# Fitness:  -235.59848822855452
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7724817683013663
# Max roll:  3.1415926533532725
# Max pitch:  1.4553123384542288
#
# [32.93237038  1.84928822  5.84035873  4.73543479  2.11874648  0.79206984]
#
# Fitness:  -290.29488495640237
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.1057310291097001
# Max roll:  0.3113891564002143
# Max pitch:  0.13414662431974647
#
# [59.92916822  1.89548488  4.49821087  5.48106335  2.34477655  0.95987774]
#
# Fitness:  -69.39140961819203
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.083614995157113
# Max roll:  0.6010841328235168
# Max pitch:  0.3014737735917006
#
# [34.69131466  1.97397667  6.23380868  4.78897392  2.58576546  0.90488633]
#
# Fitness:  -91.80019522390312
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.8194992648478822
# Max roll:  3.1415926533892216
# Max pitch:  0.7164986248807915
#
# [59.59358136  3.02737824  4.10115834  6.08369861  2.45316686  1.32638325]
#
# Fitness:  -254.29454921045829
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7854979975367633
# Max roll:  3.141592653407834
# Max pitch:  1.1633667448216554
#
# [27.19662173  1.67754605  5.46430065  6.71368018  2.10110018  1.07911821]
#
# Fitness:  -275.9579298622097
#
#
# Generation 48: Target at 0.9816326530612246 m
# Not converged:  False
# Convergence time:  3.7999999999999945
# Target distance:  0.0049955705422783155
# Max roll:  0.0004004464166097352
# Max pitch:  0.0012015579510551457
#
# [39.90458814  2.33919042  7.09236664  4.59083978  2.60343854  1.01230812]
#
# Fitness:  -3.9800116292288044
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.31544241940000317
# Max roll:  0.30872733113110473
# Max pitch:  0.4320624840242496
#
# [58.44835362  1.70532962  4.94841554  4.69561711  1.80566313  0.75073907]
#
# Fitness:  -88.34833914576778
#
#
# Not converged:  False
# Convergence time:  3.7499999999999947
# Target distance:  0.018332624900078226
# Max roll:  0.0007549936426917123
# Max pitch:  0.0013559159382329983
#
# [27.06125708  2.28214613  4.72324966  5.29950117  3.15200773  0.73245979]
#
# Fitness:  -4.222197977047795
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.6269164190931811
# Max roll:  0.3298158374521259
# Max pitch:  0.40641594830368794
#
# [56.42526445  1.62495691  5.41781543  4.55172557  2.87805308  0.87223821]
#
# Fitness:  -94.34991766965432
#
#
# Not converged:  False
# Convergence time:  3.7499999999999947
# Target distance:  0.0048504570704789455
# Max roll:  0.00046766391877046975
# Max pitch:  0.000564738488777505
#
# [41.85104106  2.23626526  6.37587156  4.47284786  2.52543413  0.82357345]
#
# Fitness:  -3.8986292617869727
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.6065875250684792
# Max roll:  3.141592653469968
# Max pitch:  1.431211253843438
#
# [45.08949902  2.15684888  5.33652069  6.40775563  2.06088071  0.92770545]
#
# Fitness:  -285.7719458670399
#
#
# Not converged:  False
# Convergence time:  3.8499999999999943
# Target distance:  0.008281108701589861
# Max roll:  0.0014124277138157127
# Max pitch:  0.0018764416999921467
#
# [38.30479561  1.91859915  5.22120896  4.75254062  2.60332894  0.97259958]
#
# Fitness:  -4.180065644722185
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7431633263236063
# Max roll:  0.16713287687412107
# Max pitch:  0.42740195323646146
#
# [60.11181437  2.05256814  4.47108206  4.13181392  1.76637932  1.14693516]
#
# Fitness:  -89.59000803200124
#
#
# Not converged:  False
# Convergence time:  3.899999999999994
# Target distance:  0.02962291369920426
# Max roll:  0.0012263778839640784
# Max pitch:  0.0017586689243117308
#
# [29.05554571  1.88605044  6.63399833  5.58821525  2.28480638  0.68200543]
#
# Fitness:  -4.64171061439787
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.6916319370655991
# Max roll:  3.1415926518206994
# Max pitch:  1.3434976644880001
#
# [54.22131043  1.82292822  4.77230136  5.73198937  1.84412276  1.07636794]
#
# Fitness:  -283.08715455674695
#
#
# Generation 49: Target at 1.0 m
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7975983685827693
# Max roll:  3.141592653577417
# Max pitch:  1.4323257162891987
#
# [39.56801873  2.13433972  6.40209015  4.37845691  2.53437363  1.06441616]
#
# Fitness:  -289.64788586498616
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7773033438081951
# Max roll:  3.1415926535655285
# Max pitch:  1.0124503970051875
#
# [49.71855361  2.36881808  7.77485781  5.14351522  2.44593138  0.69693764]
#
# Fitness:  -268.2482194046997
#
#
# Not converged:  False
# Convergence time:  2.9499999999999975
# Target distance:  0.021027356659967553
# Max roll:  0.0007346502521093104
# Max pitch:  0.0009481688444931774
#
# [39.58547237  2.7802121   5.55499931  3.5110825   2.62042028  0.86309559]
#
# Fitness:  -3.454688088029473
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7969318420874111
# Max roll:  3.1415926527314877
# Max pitch:  1.404691388298386
#
# [47.00680146  1.92686003  5.00662263  3.95776512  2.33690427  1.01931549]
#
# Fitness:  -288.2528388932419
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.8014461470793801
# Max roll:  3.1415926527483693
# Max pitch:  1.1117662091546436
#
# [33.69077721  2.61584223  7.69816408  4.68659963  3.00044886  1.12176274]
#
# Fitness:  -273.69686603673824
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.6290483718296367
# Max roll:  3.1415926529839515
# Max pitch:  0.8993682520915631
#
# [33.69080798  1.79144422  6.01313876  4.35340943  2.0423887   1.00164535]
#
# Fitness:  -259.6290126903684
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.610142947847949
# Max roll:  1.3141408923319609
# Max pitch:  1.0097916478796336
#
# [45.10715335  1.99105322  8.44805779  5.2263112   2.28792335  1.05679265]
#
# Fitness:  -173.39948596753868
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.7486544800838386
# Max roll:  3.1415926531300196
# Max pitch:  1.1760108849058843
#
# [36.17090779  2.0474142   5.37650276  5.11559428  2.69153212  0.98075116]
#
# Fitness:  -275.853266503472
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.822743463109214
# Max roll:  3.1415926529184364
# Max pitch:  1.3031523048781053
#
# [42.07906986  2.36667948  7.17457125  5.20321265  2.53950259  0.90353396]
#
# Fitness:  -283.69211715201135
#
#
# Not converged:  True
# Convergence time:  4.99999999999999
# Target distance:  0.5361881067219021
# Max roll:  3.1415926434105903
# Max pitch:  0.6761373897979019
#
# [33.33338507  1.73425153  5.989208    5.06489277  2.76377382  0.82389713]
#
# Fitness:  -246.61026379486265

# %%
# Create the controller
genome = pick_fittest(population, fitness_values)[-1] # Pick fittest genome

reset_individuals(1)

robot = GoPiGo3(
    handle_name="/Individual/GoPiGo3",
    target_handle_name="/Target",
    genome=genome
)

try:
    sim.setStepping(True)  # Trigger simulation step manually

    # Start simulation
    sim.startSimulation()
    
    while not sim.getSimulationStopping():
        robot.sense_and_actuate()
        sim.step()

    # Stop simulation
    sim.stopSimulation()

except:
    pass
